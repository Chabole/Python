# %% [markdown]
# # Processo trainee Equipe ZebraAerodesign - Desempenho

# %% [markdown]
# # Orientações básicas

# %% [markdown]
# - GitHub da equipe zebra: https://github.com/Zebra-Aerodesign
#
# ## Baixando e instalando anaconda navigator
#
# 1. Tutorial para baixar anaconda navigator https://www.youtube.com/watch?v=_eK0z5QbpKA
#     1. Link baixar o anaconda navigator https://www.anaconda.com/
#
# ## Configurando o git e o github
#
# 1. Baixe o git em https://git-scm.com/
# 2. Crie uma conta no Github em https://github.com
# 3. Baixe o Github desktop em https://github.com
# 4. Dúvidas sobre Github assista a playlist do prof. Gustavo Guanabara
# https://shorturl.at/rNSZ2
#
#
# ## Configurando a biblioteca zebralib
#
# 1. https://github.com/Zebra-Aerodesign/ZebraLib
# 2. Clone o repositório do Github no seu computador em C:\Users\\....\Anaconda3
# 3. Vá em C:\Users\arthu\Anaconda3\Lib\site-packages
# 4. Crie um arquivo no bloco de notas chamado ZebraLib.pth e salve na pasta site-packages
# 5. Dentro do arquivo coloque o local onde está a biblioteca exemplo: C:\Users\arthu\Anaconda3\ZebraLib
# 6. Sucesso! Agora é só importar a biblioteca no seu código e se divertir ... :)
#
# # Entender mais sobre programação básica e avançada
#
# ## Básica - Canal curso em video prof. gustavo guanabara link das playlist
#
# 1. Curso de algorimos e lógica de programação: https://youtu.be/8mei6uVttho
# 2. Programação em python mundo 1: https://youtu.be/S9uPNppGsGo
# 3. Programação em python mundo 2: https://youtu.be/nJkVHusJp6E
# 4. Programação em python mundo 3: https://youtube.com/playlist?list=PLHz_AreHm4dksnH2jVTIVNviIMBVYyFnH
# 5. Programação em python exercícios: https://youtube.com/playlist?list=PLHz_AreHm4dm6wYOIW20Nyg12TAjmMGT-
# 6. Conceitos de Prog. orientada a objeto (assistir aulas em vermelho): https://youtu.be/KlIL63MeyMY
#
# ## Avançada - link das playlist
#
# 1. Jamal UFTPR - Cálculo numérico: https://www.youtube.com/watch?v=Ow9Hx04qnaI&list=PLleETO-tMJixSTImpC54tjToBzw38NDLr
# 2. APMonitor - Computação para engenheiros: https://www.youtube.com/watch?v=gY0sEokk2h0&list=PLLBUgWXdTBDi-E--rwBujaNkTejLNI6ap
# 3. APMonitor site - Tutoriais e exercícios: http://apmonitor.com/che263/index.php/Main/PythonIntroduction
#
# ## Onde encontrar ajuda com exemplos
#
# 1. Aprender sobre *numpy*: https://numpy.org/doc/stable/reference/routines.html
# 2. Aprender a plotar gráfico com *matplotlib*: https://matplotlib.org/stable/gallery/index.html
# 3. Aprender computação ciêntifica com *scipy*: https://docs.scipy.org/doc/scipy/reference/index.html

# %% [markdown]
# # Glossário

# %% [markdown]
# 1. **$b$** :                       Envergadura [$m$]
# 2. **$S$** :                       Área da asa [$m^2$]
# 3. **$Af$** :                      Afilamento
# 15. **$AR$** :                     Alongamento ou aspect ratio (AR) na asa retangular
# 4. **$C_L$** :                     Coeficiente de sustentação qualquer
# 4. **$CL_n$** :                    Coeficiente de sustentação com ângulo de incidência ou natural
# 5. **$C_{Lmax}$** :                Coeficiente de sustentação máximo da aeronave, Cl de estol
# 5. **$C_{LLO}$** :                 Coeficiente de sustentação para garantir a decolagem com o menor comprimento de pista possível
# 20. **$C_{D0}$** :                 Coeficiente de arrasto parasita (coef zero-lift)
# 20. **$C_{Di}$** :                 Coeficiente de arrasto induzido (coef due-lift) --> $K.C_{Lmax}^2$
# 21. **$C_D$** :                    Coeficiente de arrasto total --> $C_{D} = C_{D0} + K.C_{Lmax}^2$
# 6. **$S_{wet}$** :                 Área molhada do avião [$m^2$]
# 7. **$c$** :                       Corda média [$m$]
# 8. **$N_{max}$** :                 Fator de carga máximo estrutural do Diagrama Vn != turn_Nmax
# 8. **$\phi$** :                    Fator de efeito solo
# 8. **$\rho$** :                    Densidade do ar local [$kg/m^3$]
# 8. **$D$** :                       Força de arrasto [$N$]
# 8. **$L$** :                       Força de sustentação [$N$]
# 8. **$T$** ou **$T_d$** :          Tração disponível [$N$]
# 8. **$T_r$**  :                    Tração requerida [$N$]
# 9. **$h$** :                       Altura da asa em relação ao chão [$m$]
# 9. **$\mu$** :                     Coefiente de atrito com o solo
# 10. **$mv$** :                     Massa vazia da aeroave [$Kg$]
# 11. **$a_o$** :                    Ângulo de incidência da asa [Graus]
# 12. **$a_{max}$** :                Ângulo maximo da asa (ângulo de estol) [Graus]
# 16. **$e_{0}$** :                  Fator eficiênte de Oswald
# 17. **$K$** :                      Constante de proporcionalidade
# 18. **$MTOW$** :                   Massa total de decolagem (Maximum Take-Off Weight)[$N$]
# 18. **$M$** :                      Massa total da aeronave [$kg$]
# 19. **$W$** :                      Peso total do avião     [$N$]
# 22. **$V_{stall}$** :              Velocidade mínima em que a força de sustentação consegue equilibrar o peso da aeronave
# 23. **$V_{lo}$** :                 Velocidade de decolagem (lift-off) [ 20% maior que $V_{stall}$ ]
# 24. **$V_{l}$** :                  Velocidade de aproximação/pouso (landing) [ 30% maior que $V_{stall}$ ]
# 24. **$S_{lo}$** :                 Distância de pista necessária para a decolagem [$m$]
# 24. **$S_{l}$** :                  Distância de pista necessária para o pouso [$m$]

# %% [markdown]
# ## Decolagem
#
# Perfil da decolagem. O objetivo é calcular a **distância** de decolagem até a velocidade **$V_{lo}$** o ultimo instânte onde há contato com o solo.

# %% [markdown]
# ![Decolagem.PNG](attachment:8be2f55d-6529-419f-a924-8c294ea98334.PNG)

# %% [markdown]
# Diagrama de corpo livre do avião durante a decolagem. Onde $V_{R}$ é a velocidade com o vento relativo, $L$ força de sustentação, $D$ força de arrasto ou tração requerida, $T$ tração disponível, $F_{at}$ força de atrito com o solo, $N$ normal (relação W-L) e $W$ peso total da aeronave.

# %% [markdown]
# ![forças_atuantes_decolagem.PNG](attachment:b2dadf73-f4e1-49d3-baff-ebdab0ed8d97.PNG)

# %% [markdown]
# Força aerodinâmicas e fator de efeito solo
# \begin{equation}
#     \phi = \frac{(16h/b)^2}{1 +(16h/b)^2}
# \end{equation}
#
# \begin{equation}
#     L = \frac{1}{2}. \rho. v^2. S. C_{L}
# \end{equation}
#
# \begin{equation}
#     D = \frac{1}{2}. \rho. v^2. S. (C_{D0} + \phi. K C_{L}^2 )
# \end{equation}

# %% [markdown]
# EDO de decolagem unidimensional:
# \begin{equation}
#     \frac{\mathrm{d}v(t) }{\mathrm{d} t} = T - D - \mu_{r}(W-L)
# \end{equation}
#
# Assim, a função $v(t)$ é dada por:
# \begin{equation}
#     v(t) = \int_{0}^{t_{vlo}} T - D - \mu_{r}(W-L) dt
#     \label{eq:v(t)}
# \end{equation}
#
# Para obtenção de $s(t)$ e $a(t)$, tem-se:
# \begin{equation}
#     s(t) = \int_{0}^{t_{vlo}} v(t) dt
#     \label{eq:s(t)}
# \end{equation}
#
# \begin{equation}
#     a(t) = \frac{\mathrm{d}v(t) }{\mathrm{d} t}
#     \label{eq:a(t)}
# \end{equation}
#
# Aproximação da distância de decolagem, pelo miranda
#
# \begin{equation}
#     S_{lo} = \frac{1.44W^2}{g S \rho C_{Lmax} [ T-[D + \mu(W-L)] ] }_{0.7V_{lo}}
# \end{equation}

# %%
import ZebraLib as zb
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#Avião para ser analisado
Zb = zb.Airplane(name='Versão 3.0', b=1.86, S=0.843, Af=0.601, c=0.463, CLmax= 1.5193, 
              Load=5.5, mv=2.8, CLn=1.080, Nmax=2.1, z=0.22, Swet= 10, Tc=(-0.001, -0.225, 35.225))

# %%
Zb.airplane_Info(zb.alt2rho(1212))
# Out:
#                                 0
# Alt-dens [m]          1212.000000
# Densidade [Kg/m^3]       1.088654
# Carga paga [Kg]          5.500000
# Carga vazia [Kg]         2.800000
# Carga total [Kg]         8.400000
# S                        0.843000
# b                        1.860000
# Swet                    10.000000
# C_D0                     0.115658
# CLn                      1.080000
# CLmáx                    1.519300
# c                        0.463000
# AR                       4.103915
# Af                       0.601000
# CLmax_Alc                1.090895
# CLmax_Aut                1.889486
# Eficmax                  4.716024
# Vstall [m/s]            10.871979
# VtakeOff  [m/s]         12.502776
# Vlanding  [m/s]         14.133572
# VstruturalMax [m/s]     15.754994
# Vcruise [m/s]           14.179495
# VmáxAlcance [m/s]       12.830360
# VmáxAutonomia  [m/s]     9.748965

# %%
# Densidade do ar desejado
Dens = zb.alt2rho(1212)

#PLOTAGEM
fig, ax = plt.subplots(figsize=(17, 6),nrows=1, ncols=2)
fig.suptitle(r'Corrida de decolagem para alt-densidade de 1212m ' + f'Carga paga {Zb.Load:.2f}Kg')

#CONSTRUINDO O 1 SUBGRÁFICO   
ax[0].set(title= 'Forças atuantes x tempo ', xlabel='tempo [s]',ylabel='Forças aerodinâmicas [N]')
ax[1].set(title= 'Forças atuantes x distância', xlabel='Distância [m]',ylabel='Forças aerodinâmicas [N]')

#Metodos para dinamica de de colagem
Vlo_index, _V, T, L, D, Fat = Zb.takeOff_Forces(Dens)

# Métodos para cinemática de decolagem
t, d, V, a = Zb.takeOff_Kinematic_EDO(rho=Dens)

#Vetores de plotagem 
Forças = np.array((T, L, D, Fat, Fat/Zb.mi, T - (D + Zb.mi*(Zb.W - L))))
Nomes = np.array((f'Tração disponível carga de {Zb.Load}Kg', 'Sustentação', 'Arrasto', 'Força de atrito ', 'Relação W-L', 'Tração líquida'))

#Plotando os dados para o avião 
for Força, Nome in zip(Forças, Nomes):
    ax[0].plot(t, Força, label = Nome)
    ax[1].plot(d, Força, label = Nome)
    
#Linhas verticais
ax[0].plot([t[Vlo_index]]*2, [0,250], linestyle=marks, color='black' , label = f'Instânte de decolagem')
ax[1].plot([d[Vlo_index]]*2, [0,250], linestyle=marks, color='black' , label = f'Espaço de decolagem')

#Deixando bonito o gráfico
for i, num in enumerate([8, 55]):
    ax[i].set_ylim(0, 150)
    ax[i].set_xlim(0, num)
    ax[i].legend()
    ax[i].grid(linestyle='dotted', linewidth=1)

# %%
V = np.linspace(0.1, 30)

fig, ax = plt.subplots(figsize=(17, 6), ncols=2, nrows=1) #criando a figura
ax[0].set(title=r'Tipo de arrastos para diferentes $b$', xlabel='Velocidade (m/s)', ylabel='Força de arrasto (N)')  
ax[1].set(title=r'Tipo de arrastos para diferentes $C_{D0}$', xlabel='Velocidade (m/s)', ylabel='Força de arrasto (N)')  

#Adcionando linhas a figura
Envergaduras = np.array((1.84, 2.2))
Coef_parasitas = np.array((0.08, 0.12))

for b, Cd0 in zip(Envergaduras, Coef_parasitas):
    Zb.b = b
    Zb.params_Calc
    
    Drag_ind = Zb.drag_Force_Induced(V, rho=1.08)
    Drag_paras = Zb.drag_Force_Parasitic(V, rho=1.08)

    ax[0].plot(V, Drag_ind, label=f'Arrasto induzido b={Zb.b}m') 
    ax[0].plot(V, Drag_paras, label=f'Arrasto parasita b={Zb.b}m')
    ax[0].plot(V, Drag_paras+Drag_ind, '--',label=f'Arrasto total b={Zb.b}m')
    
for Cd0 in Coef_parasitas:
    Zb.b = 1.86
    Zb.params_Calc
    Zb.C_D0 = Cd0
    
    Drag_ind = Zb.drag_Force_Induced(V, rho=1.08)
    Drag_paras = Zb.drag_Force_Parasitic(V, rho=1.08)

    ax[1].plot(V, Drag_ind, label=f'Arrasto induzido C_D0={Zb.C_D0}') 
    ax[1].plot(V, Drag_paras, label=f'Arrasto parasita C_D0={Zb.C_D0}')
    ax[1].plot(V, Drag_paras+Drag_ind, '--',label=f'Arrasto total C_D0={Zb.C_D0}')

for i in range(2):
    ax[i].set_ylim(0, 50)
    ax[i].set_xlim(0, 30)
    ax[i].legend()
    ax[i].grid(linestyle='dotted', linewidth=1)

# %%
# Definindo domínio
t_final = 8
pesos = np.linspace(4, 6.5, 3)

# Colores e marcadores (beautilfy)
Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen'))
Markers = np.array(('^', 'o', 'd', 'v', '.'))
Lines = np.array(('--', '-', '--', '--'))

# Gráficos
fig, ax = plt.subplots(figsize=(22, 5.5),nrows=1, ncols=3)

ax[0].set(title='Velocidade na decolagem',
       xlabel='Tempo (s)', ylabel='Velocidade (m/s)')
ax[1].set(title='Aceleração na decolagem',
        xlabel='Tempo (s)', ylabel='Acelerção $(m/s^2)$')
ax[2].set(title='Espaço na decolagem', xlabel='Tempo (s)',
        ylabel='Distância de pista (m)')

for (p, cor, mark) in zip(pesos, Cores, Markers):
    Zb.Load = p
    Zb.params_Calc
    
    tempo, S_off, V_off, a_off = Zb.takeOff_Kinematic_EDO(t_final)
    Vlo_index = zb.get_index_of_nearest_element(V_off, Zb.veloc_Req(Zb.CLmax)*1.2)
    
    ax[0].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)
    ax[1].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)
    ax[2].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)  #Intantes de decolagem
    
    ax[0].plot(tempo, V_off, color=cor, label=f'Carga paga {p:.2f}Kg')
    ax[1].plot(tempo, a_off, color=cor, label=f'Carga paga {p:.2f}Kg')
    ax[2].plot(tempo, S_off, color=cor, label=f'Carga paga {p:.2f}Kg')
    
for graf in ax:
    graf.legend()
    graf.set_xlim(0)
    graf.set_ylim(0)
    graf.grid(linestyle='dotted')

# %%
#Avião para ser analisado
Zb = zb.Airplane(name='Versão 3.0', b=1.86, S=0.843, Af=0.601, c=0.463, CLmax= 1.5193, 
              Load=5.5, mv=2.8, CLn=1.080, Nmax=2.1, z=0.22, Swet= 10, Tc=(-0.001, -0.225, 35.225))

Pesos = np.linspace(4, 7.5, 50)

fig, ax = plt.subplots(figsize=(17, 6), nrows=1, ncols=2)
ax[0].set(title='Distância de decolagem', xlabel='Distância de decolagem (m)', ylabel='Carga paga (Kg)')

#PLOTAGEM DA ESQUERDA
#-------------------------------------------------------------
S1, S2, S3 = np.empty_like(Pesos), np.empty_like(Pesos), np.empty_like(Pesos)
for i, w in enumerate(Pesos):
    Zb.Load = w
    Zb.params_Calc
    S1[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(912))
    S2[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(1212))
    S3[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(1512))
    
ax[0].plot(S1, Pesos, '--' , label=r'Alt-dens $\sigma_{min}$ 1139m')
ax[0].plot(S2, Pesos, label=r'Alt-dens de SJC 1212m ')
ax[0].plot(S3, Pesos, '--', label=r'Alt-dens $\sigma_{máx}$ 1285m')

ax[0].vlines(50, 4, 7.5, linestyles = 'dotted', color='red', label='Limite de pista pelo regulamento')    
#ax[0].set_ylim(4, 7.5)
#ax[0].set_xlim(0, 100)
ax[0].legend()
ax[0].grid(linestyle='dotted')

# ---------------------------------------------
#PLOTAGEM DA DIREITA

Densidade = np.linspace(1.225, 0.8) 
AltDens = zb.iterate_rho2alt(Densidade)
pesos = np.linspace(5, 7, 4) 

#INSPIRADO NA AIRBUS
ax[1].set(title='Altitude-Densidade x  Distância de decolagem', xlabel=' Distância de decolagem [m]',
          ylabel='Altitude-Densidade [m]', label=' - Sem efeito solo e -- com efeito solo')

# Considerando o efeito solo do avião 'True'
for w in pesos:
    Zb.Load = w
    Zb.params_Calc 
    S = np.empty_like(Densidade)
    for i, dens in enumerate(Densidade):
        S[i] =  np.array(Zb.takeOff_Distance_EDO(dens, True))
    ax[1].plot(S, AltDens, label= f'Carga paga de {Zb.Load:.2f}Kg' )

ax[1].plot([-5,180], [1212]*2,  linestyle='dashdot', color= 'r', label= 'Altitude-Densidade de SJC 1212m' )
ax[1].set_ylim(0, 4000)
ax[1].set_xlim(15,70)
ax[1].legend()
ax[1].grid(linestyle='dotted', linewidth=1)

# %% [markdown]
# ### Desafio 1
# Determine o $AR$, alongamento da asa, **com programação orientada a objeto**.
#
# \begin{equation}
#     AR = \frac{b^2}{S}
# \end{equation}
#
# Dados: $b = 2.48m$ e $S = 0.90m^2$
#
# *Algoritmo para programação*
# 1. Crie uma classe 'avião'.
# 2. Crie o construtor da classe que receba 2 parametros $(S, b)$.
# 3. $AR$ é um atributo da classe e deve ser calculado no construtor.
#
# *Resp*: $AR=6.83$

# %%
import numpy as np
import matplotlib.pyplot as plt

#Classe 
class avião:
    def __init__(self, S, b): #Construtor da classe
        self.S = S
                         #Atributos                                 
        self.AR =

# %% [markdown]
# ### Desafio 2
# Construa um método pra calcular a velocidade de estol **utilizando a classe avião**.
#
# \begin{equation}
#     V_{estol} = \sqrt{\frac{2.W}{\rho . S. C_{L_{max}}}}
# \end{equation}
#
# Dados: $\rho = 1.225kg/m^3, b=2.48m, S = 0.90m^2, C_{Lmax} = 1,65, W=150N$
#
# *Algoritmo para programação*
# 1. Crie uma classe 'avião'.
# 2. Crie o construtor da classe que receba 3 parametros $(S, b, C_{L_{max}})$.
# 3. $AR$ é um atributo da classe e deve ser calculado no construtor.
# 4. Implementar um método pra calcular a $V_{stol}$ tendo como argumento do método $W e \rho$
#
# *Resp*: $V_{estol}=12.84m/s$

# %%
#Classe 
class avião:
    def __init__(self, S, b, CLmax): #Construtor da classe
        self.S = S
                        #Atributos da classe
        self.AR =  
        
    #Método da classe abaixo
    
    #Método velocidade de estol
    def v_Stol(self, W, rho): # Argumentos do método (W e rho)
         pass

# %% [markdown]
# ### Desafio 3
# Utilize a classe do desafio 2 para plotar um gráfico um gráfico de velocidade de stol por densidade do ar ( $V_{stol}$ x $\rho$). Plote as curvas para 3  pesos diferentes.
#
# *Dados*: $W_1 = 85N, W_2= 100N, W_3=150N$

# %%
#Instanciar o objeto


#Cria um vetor de densidades de 0.6 até 1.225 com 50 elementos 
densidade = np.linspace(0.6, 1.225, 50)

#Aplicar o método V_stol(150, rho) para gerar o vetor de velocidades
velocidade_85N = 
velocidade_100N = 
velocidade_150N = 


#Plotagem
fig, ax = plt.subplots() #criando janela
ax.set(title=r'$V_{stol}$ x $\rho$', xlabel=r'Densidade do ar [$kg/m^3$]', ylabel='$V_{stol}$ [$m/s$]') #nomes dos eixos e titulo

ax.plot(densidade, velocidade_85N, label=r'$V_{stol}$ pra W=85N') #plotagem do dados
ax.plot(densidade, velocidade_100N, label=r'$V_{stol}$ pra W=100N') #plotagem do dados
ax.plot(densidade, velocidade_150N, label=r'$V_{stol}$ pra W=150N') #plotagem do dados

ax.legend() #legenda
ax.grid(linestyle='dotted') #grid do fundo

# %% [markdown]
# ### Desafio 4

# %% [markdown]
# Implemente 3 novos métodos dentro da classe avião. Um para calcular a força de sustentação $L$, outro o arrasto $D$ e para calcular o efeito solo $\phi$.
#
# \begin{equation}
#     L = \frac{1}{2}. \rho. v^2. S. C_{L}
# \end{equation}
#
# \begin{equation}
#     D = \frac{1}{2}. \rho. v^2. S. (C_{D0} + \phi. K C_{L}^2 )
# \end{equation}
#
# \begin{equation}
#     \phi = \frac{(16h/b)^2}{1 +(16h/b)^2}
# \end{equation}
#
# Calcule o efeito solo  $\phi$, força de sustentação $L$ e força de arrasto $D$. Para velocidade de 15$m/s$, $C_L = 1.5$ e $\rho = 1.225kg/m^3$.
#
# *Dados:* $b=2.48, S = 0.90m^2, C_{Lmax} = 1.65, C_{D0}=0.022, h=0.35m$
#
# *Algoritmo para programação*
# 1. Adicione 2 novos atributos no construtor $C_{D0}$ e $h$.
# 2. Já será calcula pra vc a constante $K$ no construtor.
# 3. Implemente: **efeito_Solo(self)** um método que calcula ($\phi$) e busca a altura $h$ como atributo do avião (self.h).
# 4. Implemente: **sustentação(self, V, CL, rho)** um método que calcula ($L$) com 3 argumentos de entrada. Velocidade, Cl qualquer, densidade do ar.
# 4. Implemente: **arrasto(self, V, CL, rho)** um método que calcula ($D$) com 3 argumentos de entrada. Velocidade, Cl qualquer, densidade do ar.
#
# *Resp*: $D=17.22N, L=186.05, \phi=0.843$

# %%
#Classe 
class avião:
    def __init__(self, S, b, CLmax, C_D0, h): #Construtor da classe
        self.S = S
                      #Atributos da classe
            
        self.AR = pass
        self.K = 1/(np.pi*0.75*self.AR)
        
    #Método da classe
    def v_Stol(self, W, rho): # Argumentos do método (W e rho)
        pass
    
    def efeito_Solo(self):  # Sem argumentos
        pass
    
    def sustentação(self, V, CL, rho):
        pass
    
    def arrasto(self, V, CL, rho):
        pass

# %% [markdown]
# ### Desafio 5
# *(Exemplo 4.9 - Pag 214. Miranda)* Determine o $C_{L}$ ideal para se garantir
# uma decolagem com o menor comprimento de pista possível, conhecido como ($C_{LLO}$).
#
# \begin{equation}
#     C_{LLO} = \frac{\pi.e_{0}.AR.\mu}{2 \phi}
# \end{equation}
#
# Dados: $b = 2.48m$, $S = 0.90m^2$, $e_{0}$ = 0.717,  $C_{Lmax} = 1.65$, $\mu = 0,030$, $h=0.35m$ e $C_{D} = 0.022$
#
# *Algoritmo para programação*
# 1. Implemente: **CLL0_Ideal(self, mi)** um método que calcula o ideal para se garantir a decolagem com o menor comprimento de pista possível.
#
# *Dica*
# 1. Execute o método **efeito_Solo()** dentro do método **CLL0_Ideal(mi)**
#
# *Resp*: $C_{LLO}=0.276$

# %%
#Classe 
class avião:
    def __init__(self, S, b, CLmax, C_D0, h): #Construtor da classe
        self.S = S
                         #Atributos da classe
        self.AR = 
        self.K = 1/(3.14*0.75*self.AR)
        
    #Método da classe
    def v_Stol(self, W, rho): # Argumentos do método (W e rho)
        pass
    
    def efeito_Solo(self):
        pass
    
    def sustentação(self, V, CL, rho):
        pass
    
    def arrasto(self, V, CL, rho):
        pass
    
    def CLL0_Ideal(self, mi):
        phi = self.efeito_Solo()
        pass

# %% [markdown]
# ### Desafio 6
# *(Exemplo 4.10 - Pag 217. Miranda)* Determine o comprimento de pista $ S_{lo}$ necessário para a decolagem com um peso total de $150N$ em uma pista localizada ao nível do mar $\rho$ =
# 1,225$kg/m^3$.
#
# \begin{equation}
#     S_{lo} = \frac{1.44W^2}{g S \rho C_{Lmax} [ T-[D + \mu(W-L)] ] }_{0.7V_{lo}}
# \end{equation}
#
# *Dados:* $b=2.48, S = 0.90m^2, C_{Lmax} = 1.65, C_{D0}=0.12, h=0.35m, \mu=0.03$
#
# *Algoritmo para programação*
# 1. Implemente: **distancia_decolagem(self, W, rho)** um método que calcula a distância de decolagem (Equação acima).
#
# *Algoritmo de para o método*
# 1. Considere tração disponível $T=25N$
# 1. Encontre a velocidade de decolagem $V_{lo} = 1.2V_{estol}$
# 2. Calcule o $C_{LLO}$ para substituir em $L$ e $D$.
# 3. Calcule $L$ e $D$ na velocidade igual a $0.7V_{lo}$.
# 4. Por fim, calcule $S_{lo}$
#
# *Resp*: $S_{lo}=65.85m$

# %%
#Classe 
class avião:
    def __init__(self, S, b, CLmax, C_D0, h): #Construtor da classe
        self.S = S
                         #Atributos da classe
            
        self.AR = 
        self.K = 1/(3.14*0.75*self.AR)
        
    #Método da classe
    def v_Stol(self, W, rho): # Argumentos do método (W e rho)
        pass
    
    def efeito_Solo(self):
        pass
    
    def sustentação(self, V, CL, rho):
        pass
    
    def arrasto(self, V, CL, rho):
        pass
    
    def CLL0_Ideal(self, mi):
        phi = self.efeito_Solo()
        pass
    
    def distancia_decolagem(self, W, rho, mi):
        #Tração constante
        T = 33.207
        
        #Calculando velocidade de decolagem
        vlo = self.v_Stol(W, rho)*1.2
        
        #Calculando a força de sustentação
        L = self.sustentação(0.7*vlo, CLLO, rho)
        
        #Calcule a distância percorrida
        slo =
        return slo

# %% [markdown]
# ## Manobra

# %% [markdown]
# Fator de carga limitado pela estrutura do avião (fixo), propulsivamente e por sustentação
#
# \begin{equation}
#     n_{max} = 2.1
# \end{equation}
#
# \begin{equation}
#     n_{C_L{max}} = \frac{1}{2} \rho V^2 \frac{C_L{max}}{W/S}
# \end{equation}
#
# \begin{equation}
#     n_{prop} =  \left \{ \frac{\frac{1}{2}\rho V^2}{K(W/S)}\left [ \left ( \frac{T(V, \rho)}{W} \right ) - \left ( \frac{1}{2} V^2 \frac{C_{D0}}{W/S} \right ) \right ]  \right \}^\frac{1}{2}
# \end{equation}
#
# Equacionamento do avião de inclinação máxima $\phi$, raio de curva $R$ e razão de curva $\frac{d \psi}{dt}$.
#
# \begin{equation}
#     \phi = Arcos(1/n)
# \end{equation}
#
# \begin{equation}
#     R = \frac{V^2}{g \sqrt{n^2 - 1}}
# \end{equation}
#
# \begin{equation}
#     \frac{d \psi}{dt} = \frac{g \sqrt{n^2 - 1}}{V}
# \end{equation}

# %%
V = np.linspace(0.01, 40, 1000)
dens = 1.0887   # Densidade do ar

Np, phip = Zb.turn_Nprop(V, dens)  # Cálculo dos fatores de carga
Ns, phis= Zb.turn_Nsust(V, dens)

#=========================================       FIGURA 1           ==================================

fig, ax = plt.subplots(figsize=(10, 10),nrows=2, ncols=1)

#SUBPLOT 1
#Fator de carga durante as curvas
ax[0].set(title=f'Fator de carga ($n$) para alt-dens {round(zb.alt2rho(rho=dens))}m',
       xlabel='Velocidade [m/s]', ylabel='Fator de carga máximo [g]')

ax[0].plot(V, Np, color='b', label='limite propulsivo')
ax[0].plot(V, Ns,'--',  color='red', label='limite de estol')
ax[0].axhline(y=Zb.Nmax, ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[0].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 22)
ax[0].set_ylim(0, 4)
ax[0].grid(linestyle='dotted')
ax[0].legend()

#SUBPLOT 2
#Inclinação das asas durante a curva 'phi' 
ax[1].set(title= r'Ângulo de inclinação ($\phi$) para alt-dens ' + f'{round(zb.alt2rho(rho=dens))}m',
       xlabel='Velocidade [m/s]', ylabel='Fator de carga máximo [g]')

ax[1].set(ylabel=r'Ângulo de inclinação $\phi$ [graus]', xlabel='Velocidade [m/s]')

ax[1].plot(V, phip, color='b', label='limite propulsivo')
ax[1].plot(V, phis,'--', color='red', label='limite limite de estol')
ax[1].axhline(y=np.degrees(np.arccos(1/Zb.Nmax)), ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[1].set_ylim(0)
ax[1].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 22)
ax[1].grid(linestyle='dotted')
ax[1].legend()

#=========================================       FIGURA 2            ==================================

#Raio de curva
Rp = Zb.turn_Radius(V, Np)          #Limite propulsivo
Rs = Zb.turn_Radius(V, Ns)          #Limite pelo estol da asa (CL)
Rstr = Zb.turn_Radius(V, Zb.Nmax)   #Limite estrutural de Nmáx 

#Razão de curva
Wp = Zb.turn_Rate(V, Np)            #Limite propulsivo
Ws = Zb.turn_Rate(V, Ns)            #Limite pelo estol da asa (CL)
Wstr = Zb.turn_Rate(V, Zb.Nmax)     #Limite estrutural de Nmáx 

fig, ax = plt.subplots(figsize=(10, 10),nrows=2, ncols=1) 

#SUBPLOT 1
#Raio de curva 
ax[0].set(title=f'Raio de curva mínimo para alt-dens {round(zb.alt2rho(rho=dens))}m', 
       ylabel='Raio de curva [m]', xlabel='Velocidade de voo [m/s]')

ax[0].plot(V, Rp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax[0].plot(V, Rs, '--', color='red', label='Limite de estol')
ax[0].plot(V, Rstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[0].set_ylim(0, 50)
ax[0].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 22)

ax[0].grid(linestyle='dotted')
ax[0].legend()

#SUBPLOT 2
#Razão de curva
ax[1].set(title=r'Razão de curva ($d \psi /dt$)',ylabel='Razão de curva [graus/s]'
       , xlabel='Velocidade de voo [m/s]')

ax[1].plot(V, Wp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax[1].plot(V, Ws, '--', color='red', label='Limite de estol')
ax[1].plot(V, Wstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[1].set_ylim(0, 100)
ax[1].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 22)
ax[1].grid(linestyle='dotted')
ax[1].legend()
# Out:
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1171: RuntimeWarning: invalid value encountered in sqrt
#   N = (A * (B - C)) ** 0.5
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1263: RuntimeWarning: invalid value encountered in sqrt
#   R = V ** 2 / (g * (n ** 2 - 1) ** 0.5)
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1326: RuntimeWarning: invalid value encountered in sqrt
#   w = (g * (((n ** 2) - 1) ** 0.5)) / V
