# %% [markdown]
# # Ensaios das hélices

# %% [markdown]
# ## Tração e potência dinâmica

# %%
import ZebraLib as zb
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dens = zb.alt2rho(1212)

Zb1 = zb.Airplane(b=1.8, S=0.684, Af=0.556, c=0.392, CLmax= 1.613, CLn=1.111, mv=2.8, Load= 5, Swet=10, Tc=(-0.001, -0.225, 35.225))
Zb2 = zb.Airplane(b=1.8, S=0.684, Af=0.556, c=0.392, CLmax= 1.613, CLn=1.111, mv=2.8, Load= 5, Swet=10, Tc=(-0.007, -0.05, 33.8))  #Constrói os objetos
Zb3 = zb.Airplane(b=1.8, S=0.684, Af=0.556, c=0.392, CLmax= 1.613, CLn=1.111, mv=2.8, Load= 5, Swet=10, Tc=(-0.005, -0.09, 32.8))

V =np.linspace(0.1, 25)

fig, ax = plt.subplots()

ax.set(title= 'Tração com altitude-densidade de 1212m', xlabel=' Velocidade de voo [m/s]',
          ylabel=' Tração [N]')

ax.plot(V, Zb1.trac_Available(V), label='12.25x3.75SF', color = 'blue')
ax.plot(V, Zb2.trac_Available(V), label='13x4 ', color = 'fuchsia')
ax.plot(V, Zb3.trac_Available(V), label='13x4W', color = 'purple')

ax.grid(linestyle='dotted')
ax.legend()

fig, ax = plt.subplots(figsize=(15, 5),nrows=1, ncols=2)
ax[0].set(title= 'Potências com altitude-densidade de 1212m', xlabel=' Velocidade de voo [m/s]',
          ylabel=' Potências [W] ')

ax[1].set(title=f'Sobra de potência altitude-densidade de 1212m', xlabel=' Velocidade de voo [m/s]',
          ylabel=' Potências [W] ')

ax[0].plot(V, Zb1.pot_Req(V, rho=dens), label = 'Potência requerida', color = 'red')
ax[0].plot(V, Zb1.pot_Available(V, rho=dens), label='12.25x3.75SF', color = 'blue')
ax[0].plot(V, Zb2.pot_Available(V, rho=dens), label='13x4 ', color = 'purple')
ax[0].plot(V, Zb3.pot_Available(V, rho=dens), label='13x4W', color = 'fuchsia')

ax[0].set_xlim(0, 25)
ax[0].set_ylim(0, 1000)
ax[0].grid(linestyle='dotted')
ax[0].legend()

ax[1].plot(V, Zb1.pot_Dif(V, rho=dens), label = 'Sobra de Potência 12.25x3.75SF', color = 'blue')
ax[1].plot(V, Zb2.pot_Dif(V, rho=dens), label = 'Sobra de Potência 13x4', color = 'fuchsia')
ax[1].plot(V, Zb3.pot_Dif(V, rho=dens), label = 'Sobra de Potência 13x4W', color = 'purple')

ax[1].set_xlim(0, 25)
ax[1].set_ylim(0, 200)
ax[1].grid(linestyle='dotted')
ax[1].legend()

# %% [markdown]
# ## Instanciando o avião pra simulação

# %%
#Avião para ser analisado
Zb = zb.Airplane(name='Versão 3.0', b=1.86, S=0.843, Af=0.601, c=0.463, CLmax= 1.5193, 
              Load=5.5, mv=2.8, CLn=1.080, Nmax=2.1, z=0.22, Swet= 10, Tc=(-0.001, -0.225, 35.225))

# %% [markdown]
# # Trações e potências do avião

# %% [markdown]
# \begin{equation}
#     C_{Lr} = \frac{2L}{\rho v^2 S}
# \end{equation}
#
# \begin{equation}
#     D=T_{R} = \frac{1}{2} \rho v^2 S ( C_{D0} + \frac{C_{Lr}^2}{\pi e_{0} AR})
# \end{equation}

# %%
"""
Created on Tue Apr  6 15:37:52 2021

@author: Arthur Chabole
=========================================
Este programa calcula as trações, potências diponíveis e requeridas.

figura 1 - Trações diponível e requeridas
            - Fixo 1212m variando + - 300m
            - Mostrando a velocidade min, max, stall e max alcance.

figura 2 - Potência diponível e requeridas
            - Fixo 1212m variando + - 300m
            - Mostrando a velocidade min, max, stall e max autonomia.
"""

#mais elementos melhor para o método find_match
V = np.linspace(0.1, 35, 1000)
rho = np.array( (1.1212, 1.0886542, 1.05678))

#rho = np.array( (alt2rho(1139), alt2rho(1212), alt2rho(1285)))

Trac_Av0 = Zb.trac_Available(V, rho[0])
Trac_Av1 = Zb.trac_Available(V, rho[1])
Trac_Av2 = Zb.trac_Available(V, rho[2])

Trac_Req0 = Zb.trac_Req(V, rho[0])
Trac_Req1 = Zb.trac_Req(V, rho[1])
Trac_Req2 = Zb.trac_Req(V, rho[2])

pot_Av0 = Zb.pot_Available(V, rho[0])
pot_Av1 = Zb.pot_Available(V, rho[1])
pot_Av2 = Zb.pot_Available(V, rho[2])

pot_Req0 = Zb.pot_Req(V, rho[0])
pot_Req1 = Zb.pot_Req(V, rho[1])
pot_Req2 = Zb.pot_Req(V, rho[2])

# ==========================================     FIGURA 1      ==============================================

fig, ax = plt.subplots(figsize=(24, 8),nrows=1, ncols=2)

ax[0].set(title=f'Trações com altitude-densidade de {round(zb.alt2rho(rho=rho[1]))}m ($\pm 300 m)$', xlabel=' Velocidade de voo [m/s]',
          ylabel=' Tração [N] ')

ax[0].plot(V, Trac_Av0, 'b--')
ax[0].plot(V, Trac_Av1, color= 'b', label= ' Tração disponível ')
ax[0].plot(V, Trac_Av2, 'b--')

ax[0].plot(V, Trac_Req0, 'r--')
ax[0].plot(V, Trac_Req1, color= 'r',label= ' Tração requerida ')
ax[0].plot(V, Trac_Req2, 'r--')

#Maximos e mínimos de velocidade + velocidade de stall e máx efic aerod
def resid(x, args):
    rho = args
    return Zb.trac_Dif(x, rho)

Vmin_index = zb.get_index_of_nearest_element(V, zb.robustNewton(resid, V.min(), args=rho[0])[0])
Vmax_index = zb.get_index_of_nearest_element(V, zb.robustNewton(resid, V.max(), args=rho[0])[0])

ax[0].plot([V[Vmin_index]]*2, [0, Trac_Req1[Vmin_index]] , 
        linestyle='dashdot', color='limegreen', 
        label= f'Velocidade mínima propulsiva ${round(V[Vmin_index],1)}m/s$')

ax[0].plot([V[Vmax_index]]*2,[0, Trac_Req1[Vmax_index]] , 
        linestyle='dashdot', color='purple', 
        label= f'Velocidade máxima propulsiva ${round(V[Vmax_index],1)}m/s$')

ax[0].plot([Zb.Vstall]*2, [0, 50], linestyle='--',
        color='magenta', label= f'Velocidade de stall ${round(Zb.Vstall,1)}m/s$')

Maxalc_index = np.where(Trac_Req1 == min(Trac_Req1))

ax[0].plot([V[Maxalc_index]]*2, [0, Trac_Req1[Maxalc_index]], 
        label=f'Velocidade de máximo alcance (max eficiência aerodinâmica) ${round(min(V[Maxalc_index]),1)}m/s$') 
 
ax[0].set_ylim(0,50)
ax[0].set_xlim(5,25)

ax[0].legend()
ax[0].grid()

# =====================================     FIGURA 2      ==============================================

#fig, ax2 = plt.subplots()
ax[1].set(title=f'Potências altitude-densidade de {round(zb.alt2rho(rho=rho[1]))}m ($\pm 300 m)$', xlabel=' Velocidade de voo [m/s]',
          ylabel=' Potências [N] ')

ax[1].plot(V, pot_Av0, 'b--')
ax[1].plot(V, pot_Av1, color= 'b', label= ' Potência disponível ')
ax[1].plot(V, pot_Av2, 'b--')

ax[1].plot(V, pot_Req0, 'r--')
ax[1].plot(V, pot_Req1, color= 'r',label= ' Potência requerida ')
ax[1].plot(V, pot_Req2, 'r--')

ax[1].plot([V[Vmin_index]]*2,[0, pot_Req1[Vmin_index]], 
        linestyle='dashdot', color='limegreen', 
        label= f'Velocidade mínima propulsiva ${round(V[Vmin_index],1)}m/s$')

ax[1].plot([V[Vmax_index]]*2, [0, pot_Req1[Vmax_index]], 
        linestyle='dashdot', color='purple',
        label= f'Velocidade máxima propulsiva$ {round(V[Vmax_index],1)}m/s$')

ax[1].plot([Zb.Vstall]*2, [0, 1100], linestyle='--', color='magenta', label= f'Velocidade de stall ${round(Zb.Vstall,1)}m/s$')

MaxAuto_index = np.where(pot_Req1 == min(pot_Req1))

ax[1].plot([V[MaxAuto_index]]*2, [0, pot_Req1[MaxAuto_index]], 
        label=f'Velocidade de máxima autonomia ${round(min(V[MaxAuto_index]),1)}m/s$') 
 
ax[1].set_ylim(0,1100)
ax[1].set_xlim(5,25)

ax[1].legend()
ax[1].grid()
# Out:
# C:\Users\arthu\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# C:\Users\arthu\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# # Decolagem

# %% [markdown]
# ## Dinâmica

# %% [markdown]
# \begin{equation}
#     L = \frac{1}{2} \rho v^2 S C_{L}
# \end{equation}
#
# \begin{equation}
#     D = \frac{1}{2} \rho v^2 S (C_{D0} + \varphi K C_{L}^2 )
# \end{equation}
#
# \begin{equation}
#     Fat = \mu_{r}(W-L)
# \end{equation}
#
# \begin{equation}
#     \phi = \frac{(16h/b)^2}{1 +(16h/b)^2}
# \end{equation}

# %%
"""
Created on Thu Mar 25 11:46:23 2021

@author: Arthur Chabole
=============================
Este programa cálcula a forças e a cinemática da decolagem para alt-dens 1212m usando a biblioteca zerbralib. 
   
 Figura 1 - Aplicando newton na decolagem para 2 cargas pagas diferentes
        Subplot 1 - Forças durante a decolagem x distância de pista
        Subplot 2 - Velocidade, aceleração e distância x Tempo
        
PROBLEMA
    - Espaço de decolagem ..... 
"""

densidade = [zb.alt2rho(912), zb.alt2rho(1212), zb.alt2rho(1512)]   #Densidade do ar desvio de 300m
Markers = ['--', '-', '--']

#PLOTAGEM
fig, ax = plt.subplots(figsize=(12, 9),nrows=1, ncols=1)
fig.suptitle(r'Corrida de decolagem para alt-densidade de 1212 $\pm$ 300 m ' + f'Carga paga {Zb.Load:.2f}')

#CONSTRUINDO O 1 SUBGRÁFICO   
ax.set(title= 'Forças atuantes ', xlabel='tempo [s]',ylabel='Forças aerodinâmicas [N]')

for Dens, marks in zip(densidade, Markers):
    
    #Metodos para dinamica de de colagem
    Vlo_index, _V, T, L, D, Fat = Zb.takeOff_Forces(Dens)

    # Métodos para cinemática de decolagem
    t, d, V, a = Zb.takeOff_Kinematic_EDO(rho=Dens)
    
    #Plotando os dados para o avião Zb1
    ax.plot(t, T, linestyle=marks, color='b', label = f'Tração disponível carga de {Zb.Load}Kg')
    ax.plot(t, L, linestyle=marks, color= 'g',label = 'Sustentação')
    ax.plot(t, D, linestyle=marks, color='r',label = 'Arrasto')
    ax.plot(t, Fat, linestyle=marks, color='c', label = ' Força de atrito ')
    ax.plot(t, Fat/Zb.mi, linestyle=marks, color='orange' , label = 'Relação W-L ') #Gambiarra para poupar trabalho "Fat/Zb.mi"

    ax.plot([t[Vlo_index]]*2, [0,250], linestyle=marks, color='black' , label = f'Espaço de decolagem {Zb.Load}Kg')
    #print(V[Vlo_index])
    ax.set_ylim(0, 200)
    ax.set_xlim(0, 8)
    ax.legend()
    ax.grid(linestyle='dotted', linewidth=1)

# %% [markdown]
# ## Cinemática

# %% [markdown]
# EDO de decolagem
# \begin{equation}
#     \frac{\mathrm{d}v(t) }{\mathrm{d} t} = T - D - \mu_{r}(W-L)
# \end{equation}
#
# Assim, a função $v(t)$ é dada por:
# \begin{equation}
#     v(t) = \int_{0}^{t_{vlo}} T - D - \mu_{r}(W-L) dt
#     \label{eq:v(t)}
# \end{equation}
# Sendo resolvida pela função odeint()
#
# Para obtenção de $s(t)$ e $a(t)$, tem-se:
# \begin{equation}
#     s(t) = \int_{0}^{t_{vlo}} v(t) dt
#     \label{eq:s(t)}
# \end{equation}
#
# \begin{equation}
#     a(t) = \frac{\mathrm{d}v(t) }{\mathrm{d} t}
#     \label{eq:a(t)}
# \end{equation}

# %%
"""
Created on Sat Jun  5 09:09:02 2021

@author: Arthur Chabole
=============================
Performance cinemática da decolagem.

"""
# Definindo domínio
t_final = 8
pesos = np.linspace(4, 6.5, 4)

# Colores e marcadores (beautilfy)
Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen'))
Markers = np.array(('^', 'o', 'd', 'v', '.'))
Lines = np.array(('--', '-', '--', '--'))

# Gráficos
fig, ax = plt.subplots(figsize=(22, 5.5),nrows=1, ncols=3)

ax[0].set(title='Velocidade na decolagem',
       xlabel='Tempo (s)', ylabel='Velocidade (m/s)')
ax[1].set(title='Aceleração na decolagem',
        xlabel='Tempo (s)', ylabel='Acelerção $(m/s^2)$')
ax[2].set(title='Espaço na decolagem', xlabel='Tempo (s)',
        ylabel='Distância de pista (m)')


for (p, cor, mark) in zip(pesos, Cores, Markers):
    
    Zb.Load = p
    Zb.params_Calc

    # Usando os métodos
    #tempo, S_on, V_on, a_on = Zb.takeOff_Kinematic_EDO(t_final, Ground_Effect=True)
    tempo, S_off, V_off, a_off = Zb.takeOff_Kinematic_EDO(t_final)

    Vlo_index = zb.get_index_of_nearest_element(V_off, Zb.veloc_Req(Zb.CLmax)*1.2)
    
    ax[0].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)
    ax[1].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)
    ax[2].axvline(x=tempo[Vlo_index], linestyle='--', ymin= 0, ymax= 20, color= cor)  #Intantes de decolagem
    
    ax[0].plot(tempo, V_off, color=cor, label=f'Carga paga {p:.2f}Kg')
    ax[1].plot(tempo, a_off, color=cor, label=f'Carga paga {p:.2f}Kg')
    ax[2].plot(tempo, S_off, color=cor, label=f'Carga paga {p:.2f}Kg')

# Formatar gráfico 4 para escala logaritmica
# ax4.set_yscale('log')
# ax4.set_ylim(0.1)

# Beautilfy
for graf in ax:
    graf.legend()
    graf.set_xlim(0)
    graf.set_ylim(0)
    graf.grid(linestyle='dotted')

# %% [markdown]
# ## Performance de decolagem - Alt-Dens x Distância

# %%
'''
Este programa calcula o comprimento de pista para decolagem x altitude-densidade para varias cargas pagas
                                                                            usando a biblioteca zebralib.    
    Figura 1 - Altitude-densidade x Distância de pista
            Com cargas diferentes.
      
    Figura 2 - Distância de pista x Altitude-densidade 
            Com cargas diferentes.
            
O efeito solo pode ser considerado ou não. Caso seja considerado, "descomente" as linhas 60-63 e 84-87
'''

Densidade = np.linspace(1.225, 0.8) 
AltDens = zb.iterate_rho2alt(Densidade)
pesos = np.linspace(5, 7, 4) 

#PLOTAGEM
fig, ax = plt.subplots(figsize=(10, 7),nrows=1, ncols=1)

#INSPIRADO NA AIRBUS
ax.set(title='Altitude-Densidade x  Distância de decolagem', xlabel=' Distância de decolagem [m]',
          ylabel='Altitude-Densidade [m]', label=' - Sem efeito solo e -- com efeito solo')

# Considerando o efeito solo do avião 'True'
for w in pesos:
    Zb.Load = w
    Zb.params_Calc #MT IMPORTANTE ESSE MÉTODO
    S, S2, S3, S4 = np.empty_like(Densidade), np.empty_like(Densidade), np.empty_like(Densidade), np.empty_like(Densidade)
    for i, dens in enumerate(Densidade):
        S[i] =  np.array(Zb.takeOff_Distance_EDO(dens, True))
    ax.plot(S, AltDens, label= f'Carga paga de {Zb.Load:.2f}Kg' )

ax.plot([-5,180], [1212]*2,  linestyle='dashdot', color= 'r', label= 'Altitude-Densidade de SJC 1212m' )
ax.set_ylim(0, 4000)
ax.set_xlim(15,70)
ax.legend()
ax.grid(linestyle='dotted', linewidth=1)

# %% [markdown]
# ## Performance de decolagem: MTOW x distância de decolagem

# %%
Pesos = np.linspace(4, 7, 50)

fig, ax = plt.subplots(figsize=(10, 7))
ax.set(title='Distância de decolagem', xlabel='Distância de decolagem (m)', ylabel='Carga paga (Kg)')

S1, S2, S3 = np.empty_like(Pesos), np.empty_like(Pesos), np.empty_like(Pesos)
for i, w in enumerate(Pesos):
    Zb.Load = w
    Zb.params_Calc
    S1[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(912))
    S2[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(1212))
    S3[i] = Zb.takeOff_Distance_EDO(rho=zb.alt2rho(1512))
    
ax.plot(S1, Pesos, '--' , label=r'Altitude-densidade $\sigma_{min}$ 1139m')
ax.plot(S2, Pesos, label=r'Altitude-densidade de SJC 1212m ')
ax.plot(S3, Pesos, '--', label=r'Altitude-densidade $\sigma_{máx}$ 1285m')

plt.vlines(50, 4, 7, linestyles = 'dotted', color='red', label='Limite de decolagem')    
ax.legend()
ax.grid(linestyle='dotted')
plt.show()

fig.savefig('D:/Semana da engenharia/Carga_paga_x_distância_TO.pdf', bbox_inches='tight')

# %%
#Voltando para oavião incial
Zb.Load = 5.5
Zb.params_Calc

# %% [markdown]
# # Subida

# %% [markdown]
# \begin{equation}
#     R/C = \frac{Pd - Pr}{W}
#     \label{eq:rc}
# \end{equation}
#
# \begin{equation}
#     \theta = arcsin(\frac{R/C}{V})
#     \label{eq:arc}
# \end{equation}
#
# \begin{equation}
#     Vh = Vcos(\theta)
#     \label{eq:v}
# \end{equation}

# %%
"""
Created on Fri Apr  2 22:48:14 2021

@author: Arthur Chabole
=============================
Este programa cálcula a razão e ângulo de subida x velocidade horizontal Vh usando a biblioteca zerbralib. 
   
 Figura 1 - Fixo a carga padrão de 5.44kg
        Subplot 1 - Razão de subida x Vh variando altitude-densidade
        Subplot 2 - Ângulo de subida x Vh variando altitude-densidade
   
 Figura 2 - Fixo a altitude-densidade de 1212m
        Subplot 1 - Razão de subida x Vh variando carga paga
        Subplot 2 - Ângulo de subida x Vh variando carga paga
        
"""

Zb.load = 5.5
Zb.params_Calc

V = np.linspace(0, 35)
Pesos = np.linspace(5, 6.5, 4)  

Densidade = [zb.alt2rho(912), zb.alt2rho(1212), zb.alt2rho(1512)]

Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen' ))
Markers= np.array(('^', 'o', 'd', 'v', '.'))
Lines = np.array(('--','-','--','--'))

# ===================================              FIGURA 1        ========================================

#SUBIDA VARIANDO A ALTITUDE-DENSIDADE USANDO 5.44kg CARGA PAGA
fig, (ax, ax2) = plt.subplots(2,1, figsize=(15,9))            #Constrói a figura com os subplots

#SUBGRÁFICO 1 DA FIGURA 1
ax.set(title= f'Subida váriando a altitude-densidade com carga de {Zb.Load}Kg', xlabel='Velocidade horizontal Vh [m/s]',
        ylabel='Razão de subida R/C [m/s]')

#SUBGRÁFICO 2 DA FIGURA 1
ax2.set(xlabel='Velocidade horizontal Vh [m/s]',
        ylabel='Ângulo de subida [graus]')

for (dens, cor, mark, line, w) in zip(Densidade, Cores, Markers, Lines, Pesos):   
    V = np.linspace(Zb.veloc_Req(Zb.CLmax, rho=dens),35)
    RC, theta = Zb.rate_Climb(V, dens)          #Cálcula as razões e os ângulos
    Vh = np.array(np.cos(np.deg2rad(theta))*V)   #Cálcula a velocidade horizontal
    
    ax.plot(Vh, RC, color=cor, marker=mark, linestyle=line, markersize=5, linewidth=0.8, 
            label= f'Razão de subida Alt-densidade {zb.alt2rho(rho=dens):.2f}m' )
    ax2.plot(Vh, theta, color=cor, marker=mark, linestyle=line, markersize=5, linewidth=0.8,
             label= f'Ângulo de subida Alt-densidade {zb.alt2rho(rho=dens):.2f}m' )

ax.set_ylim(0)
ax.set_xlim(10, 30)
ax.legend()
ax.grid(linestyle='dotted', linewidth=1)

ax2.set_ylim(0)
ax2.set_xlim(10, 30)
ax2.legend()
ax2.grid(linestyle='dotted', linewidth=1)

# ===================================             FIGURA 2           ==========================================

#SUBIDA VARIANDO A ALTITUDE-DENSIDADE USANDO 5.44kg CARGA PAGA
fig, (ax, ax2) = plt.subplots(2,1, figsize=(15,9))            #Constrói a figura com os subplots

#SUBGRÁFICO 1 DA FIGURA 1
ax.set(title= f'Subida variando o carga com alt-dens de {round(zb.alt2rho(rho= Densidade[1]),0)}m ',
        xlabel='Velocidade horizontal Vh [m/s]', ylabel='Razão de subida R/C [m/s]')

#SUBGRÁFICO 2 DA FIGURA 1
ax2.set(xlabel='Velocidade horizontal Vh [m/s]',
        ylabel='Ângulo de subida [graus]')

for (cor, mark, line, w) in zip(Cores, Markers, Lines, Pesos):
    Zb.Load = w
    Zb.params_Calc
    
    V = np.linspace(Zb.veloc_Req(Zb.CLmax, rho=zb.alt2rho(1212)),35)
    RC, theta = Zb.rate_Climb(V, zb.alt2rho(1212))          #Cálcula as razões e os ângulos
    Vh = np.array(np.cos(np.deg2rad(theta))*V)           #Cálcula a velocidade horizontal
    
    ax.plot(Vh, RC, color=cor, marker=mark, linestyle=line, markersize=5, linewidth=0.8, 
             label= f'Razão de subida carga de {(Zb.Load)}Kg' )
    ax2.plot(Vh, theta, color=cor, marker=mark, linestyle=line, markersize=5, linewidth=0.8,
             label= f'Ângulo de subida carga de {(Zb.Load)}Kg' )

ax.set_ylim(0)
ax.set_xlim(10, 30)
ax.legend()
ax.grid(linestyle='dotted', linewidth=1)

ax2.set_ylim(0)
ax2.set_xlim(10, 30)
ax2.legend()
ax2.grid(linestyle='dotted', linewidth=1)


#Voltando para oavião incial
Zb.Load = 5.5
Zb.params_Calc

# %% [markdown]
# ## Cruzeiro

# %% [markdown]
# Calculando os coeficientes de sustentação
# \begin{equation}
#     C_{L_{máx{Alcance}}} = \sqrt{\frac{C_{D0}}{K}}
# \end{equation}
#
# \begin{equation}
#     C_{L_{máx{Autonomia}}} = \sqrt{\frac{3C_{D0}}{K}}
# \end{equation}

# %% [markdown]
# Calculando as velocidades
#
# \begin{equation}
#     V_{máx_{Alcance}} = \sqrt{\frac{2W}{\rho S C_{L_{máx{Alcance}}}}}
# \end{equation}
#
# \begin{equation}
#     V_{máx_{Autonomia}} = \sqrt{\frac{2W}{\rho S C_{L_{máx{Autonomia}}}}}
# \end{equation}
#
# \begin{equation}
#     V_{estol} = \sqrt{\frac{2W}{\rho S C_{L_{máx}}}}
# \end{equation}

# %%
Zb.load = 5.5
Zb.params_Calc

rho = np.linspace(0.3, 1.225)

fig, ax = plt.subplots(figsize=(10, 5))
ax.set(ylabel='Velocidade [m/s]', xlabel='Altitude-densidade [m]')

ax.plot(zb.iterate_rho2alt(rho), Zb.veloc_Req(Zb.Clmax_Alc, rho), label='Velocidade max alcance')
ax.plot(zb.iterate_rho2alt(rho), Zb.veloc_Req(Zb.Clmax_Aut, rho), label='Velocidade max autonomia')
ax.plot(zb.iterate_rho2alt(rho), Zb.veloc_Req(Zb.CLmax, rho),'--',label='Velocidade estol')

ax.axvline(x=1212, color='red', linestyle='dashdot', label='Altitude-densidade 1212m')

ax.axvline(x=1212+73, color='red', linestyle='dotted', label=r'Altitude-densidade $(1212 \pm 73)m$')
ax.axvline(x=1212-73, color='red', linestyle='dotted')


ax.plot()
ax.set_xlim(0,6308)
ax.set_ylim(8.5,18)
ax.legend()
ax.grid(linestyle='dotted')

# %% [markdown]
# ## Manobra

# %% [markdown]
# Fator de carga limitado pela estrutura do avião (fixo), propulsivamente e por sustentação
#
# \begin{equation}
#     n_{max} = 2.1
# \end{equation}
#
# \begin{equation}
#     n_{C_L{max}} = \frac{1}{2} \rho V^2 \frac{C_L{max}}{W/S}
# \end{equation}
#
# \begin{equation}
#     n_{prop} =  \left \{ \frac{\frac{1}{2}\rho V^2}{K(W/S)}\left [ \left ( \frac{T(V, \rho)}{W} \right ) - \left ( \frac{1}{2} V^2 \frac{C_{D0}}{W/S} \right ) \right ]  \right \}^\frac{1}{2}
# \end{equation}
#
# Equacionamento do avião de inclinação máxima $\phi$, raio de curva $R$ e razão de curva $\frac{d \psi}{dt}$.
#
# \begin{equation}
#     \phi = Arcos(1/n)
# \end{equation}
#
# \begin{equation}
#     R = \frac{V^2}{g \sqrt{n^2 - 1}}
# \end{equation}
#
# \begin{equation}
#     \frac{d \psi}{dt} = \frac{g \sqrt{n^2 - 1}}{V}
# \end{equation}

# %%
"""
Created on Sun Apr  4 22:57:59 2021

@author: Arthur Chabole
====================================
Este programa calcula Fatores de carga e os angulos de inclinação phi, figura 1. E raios e razões de curvas
limitados pela potência, sustentação e estrutura do avião, figura 2. Fixados carga padrão e alt-dens 1212m
Basicamente a ideia é entender o que limita o avião na execução das curvas.

 Figura 1 - Fixo carga padrão e altitude-densidade de 1212m 
        Subplot 1 - Fator de carga x velocidade de voo
        Subplot 2 - Ângulo de inclianação x Velocidade de voo
   
 Figura 2 - Fixo carga padrão e altitude-densidade de 1212m 
        Subplot 1 - Raio de curva x velocidade de voo
        Subplot 2 - Razão de curva x velocidade de voo

"""

V = np.linspace(0.01, 40, 1000)
dens = 1.0887   # Densidade do ar

Np, phip = Zb.turn_Nprop(V, dens)  # Cálculo dos fatores de carga
Ns, phis= Zb.turn_Nsust(V, dens)

#=========================================       FIGURA 1           ==================================

fig, ax = plt.subplots(figsize=(10, 10),nrows=2, ncols=1)

#SUBPLOT 1
#Fator de carga durante as curvas
ax[0].set(title=f'Fator de carga ($n$) para alt-dens {round(zb.alt2rho(rho=dens))}m',
       xlabel='Velocidade de voo [m/s]', ylabel='Fator de carga máximo [g]')

ax[0].plot(V, Np, color='b', label='limite propulsivo')
ax[0].plot(V, Ns,'--',  color='red', label='limite de estol')
ax[0].axhline(y=Zb.Nmax, ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[0].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax[0].set_ylim(0, 4)
ax[0].grid(linestyle='dotted')
ax[0].legend()

#SUBPLOT 2
#Inclinação das asas durante a curva 'phi' 
ax[1].set(title= r'Ângulo de inclinação ($\phi$) para alt-dens ' + f'{round(zb.alt2rho(rho=dens))}m',
       xlabel='Velocidade de voo [m/s]', ylabel='Fator de carga máximo [g]')

ax[1].set(ylabel=r'Ângulo de inclinação $\phi$ [graus]', xlabel='Velocidade [m/s]')

ax[1].plot(V, phip, color='b', label='limite propulsivo')
ax[1].plot(V, phis,'--', color='red', label='limite limite de estol')
ax[1].axhline(y=np.degrees(np.arccos(1/Zb.Nmax)), ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[1].set_ylim(0)
ax[1].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax[1].grid(linestyle='dotted')
ax[1].legend()

#=========================================       FIGURA 2            ==================================

#Raio de curva
Rp = Zb.turn_Radius(V, Np)          #Limite propulsivo
Rs = Zb.turn_Radius(V, Ns)          #Limite pelo estol da asa (CL)
Rstr = Zb.turn_Radius(V, Zb.Nmax)   #Limite estrutural de Nmáx 

#Razão de curva
Wp = Zb.turn_Rate(V, Np)            #Limite propulsivo
Ws = Zb.turn_Rate(V, Ns)            #Limite pelo estol da asa (CL)
Wstr = Zb.turn_Rate(V, Zb.Nmax)     #Limite estrutural de Nmáx 

fig, ax = plt.subplots(figsize=(10, 10),nrows=2, ncols=1) 

#SUBPLOT 1
#Raio de curva 
ax[0].set(title=f'Raio de curva mínimo para alt-dens {round(zb.alt2rho(rho=dens))}m', 
       ylabel='Raio de curva [m]', xlabel='Velocidade de voo [m/s]')

ax[0].plot(V, Rp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax[0].plot(V, Rs, '--', color='red', label='Limite de estol')
ax[0].plot(V, Rstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[0].set_ylim(0, 50)
ax[0].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)

ax[0].grid(linestyle='dotted')
ax[0].legend()

#SUBPLOT 2
#Razão de curva
ax[1].set(title=r'Razão de curva ($d \psi /dt$)',ylabel='Razão de curva [graus/s]'
       , xlabel='Velocidade de voo [m/s]')

ax[1].plot(V, Wp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax[1].plot(V, Ws, '--', color='red', label='Limite de estol')
ax[1].plot(V, Wstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax[1].set_ylim(0, 100)
ax[1].set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax[1].grid(linestyle='dotted')
ax[1].legend()
# Out:
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1232: RuntimeWarning: invalid value encountered in sqrt
#   N = (A * (B - C)) ** 0.5
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1324: RuntimeWarning: invalid value encountered in sqrt
#   R = V ** 2 / (g * (n ** 2 - 1) ** 0.5)
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   w = (g * (((n ** 2) - 1) ** 0.5)) / V

# %%
"""
Created on Sun Apr  4 22:57:59 2021

@author: Arthur Chabole
====================================
Este programa calcula Fatores de carga e os angulos de inclinação phi, figura 1. E raios e razões de curvas
limitados pela potência, sustentação e estrutura do avião, figura 2. Fixados carga padrão e alt-dens 1212m
Basicamente a ideia é entender o que limita o avião na execução das curvas.

 Figura 1 - Fixo carga padrão e altitude-densidade de 1212m 
        Subplot 1 - Fator de carga x velocidade de voo
        Subplot 2 - Ângulo de inclianação x Velocidade de voo
   
 Figura 2 - Fixo carga padrão e altitude-densidade de 1212m 
        Subplot 1 - Raio de curva x velocidade de voo
        Subplot 2 - Razão de curva x velocidade de voo

"""

V = np.linspace(0.01, 40, 1000)
dens = 1.0887   # Densidade do ar

Np, phip = Zb.turn_Nprop(V, dens)  # Cálculo dos fatores de carga
Ns, phis= Zb.turn_Nsust(V, dens)

#=========================================       FIGURA 1           ==================================

fig, ax = plt.subplots(figsize=(10, 5))
fig2, ax2 = plt.subplots(figsize=(10, 5))

#SUBPLOT 1
#Fator de carga durante as curvas
ax.set(
       xlabel='Velocidade de voo [m/s]', ylabel='Fator de carga máximo [g]')

ax.plot(V, Np, color='b', label='limite propulsivo')
ax.plot(V, Ns,'--',  color='red', label='limite de estol')
ax.axhline(y=Zb.Nmax, ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax.set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax.set_ylim(0, 4)
ax.grid(linestyle='dotted')
ax.legend()

#SUBPLOT 2
#Inclinação das asas durante a curva 'phi' 
ax2.set(
       xlabel='Velocidade de voo [m/s]', ylabel='Fator de carga máximo [g]')

ax2.set(ylabel=r'Ângulo de inclinação $\phi$ [graus]', xlabel='Velocidade [m/s]')

ax2.plot(V, phip, color='b', label='limite propulsivo')
ax2.plot(V, phis,'--', color='red', label='limite limite de estol')
ax2.axhline(y=np.degrees(np.arccos(1/Zb.Nmax)), ls='-.', color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax2.set_ylim(0)
ax2.set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax2.grid(linestyle='dotted')
ax2.legend()

#=========================================       FIGURA 2            ==================================

#Raio de curva
Rp = Zb.turn_Radius(V, Np)          #Limite propulsivo
Rs = Zb.turn_Radius(V, Ns)          #Limite pelo estol da asa (CL)
Rstr = Zb.turn_Radius(V, Zb.Nmax)   #Limite estrutural de Nmáx 

#Razão de curva
Wp = Zb.turn_Rate(V, Np)            #Limite propulsivo
Ws = Zb.turn_Rate(V, Ns)            #Limite pelo estol da asa (CL)
Wstr = Zb.turn_Rate(V, Zb.Nmax)     #Limite estrutural de Nmáx 

fig3, ax3 = plt.subplots(figsize=(10, 5)) 
fig4, ax4 = plt.subplots(figsize=(10, 5)) 

#SUBPLOT 1
#Raio de curva 
ax3.set( 
       ylabel='Raio de curva [m]', xlabel='Velocidade de voo [m/s]')

ax3.plot(V, Rp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax3.plot(V, Rs, '--', color='red', label='Limite de estol')
ax3.plot(V, Rstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax3.set_ylim(0, 50)
ax3.set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)

ax3.grid(linestyle='dotted')
ax3.legend()

#SUBPLOT 2
#Razão de curva
ax4.set(ylabel='Razão de curva [graus/s]'
       , xlabel='Velocidade de voo [m/s]')

ax4.plot(V, Wp, linestyle='dashdot', color='royalblue', label='Limite propulsivo')
ax4.plot(V, Ws, '--', color='red', label='Limite de estol')
ax4.plot(V, Wstr, color='green', label=f'Limite estrutural de ${Zb.Nmax}g$')

ax4.set_ylim(0, 100)
ax4.set_xlim(Zb.veloc_Req(Zb.CLmax, zb.alt2rho(1212)), 25)
ax4.grid(linestyle='dotted')
ax4.legend()

fig.savefig('D:/Semana da engenharia/fator_carga.pdf', bbox_inches='tight')
fig2.savefig('D:/Semana da engenharia/inclinação_asas.pdf', bbox_inches='tight')
fig3.savefig('D:/Semana da engenharia/raio_curva.pdf', bbox_inches='tight')
fig4.savefig('D:/Semana da engenharia/razão_curva.pdf', bbox_inches='tight')
# Out:
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1232: RuntimeWarning: invalid value encountered in sqrt
#   N = (A * (B - C)) ** 0.5
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1324: RuntimeWarning: invalid value encountered in sqrt
#   R = V ** 2 / (g * (n ** 2 - 1) ** 0.5)
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   w = (g * (((n ** 2) - 1) ** 0.5)) / V

# %% [markdown]
# ## Descida

# %% [markdown]
# Equacionamento
# \begin{equation}
#     \theta = \frac{1}{C_{L}/C_{D}}
# \end{equation}
#
# \begin{equation}
#     V = \sqrt{ \frac{2W cos(\theta)}{\rho S C_{L}}}
# \end{equation}
#
# \begin{equation}
#     RS = V sen(\theta)
# \end{equation}
#
# \begin{equation}
#     V_{h} = V cos(\theta)
# \end{equation}

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Apr  4 09:04:08 2021

@author: Arthur Chabole
====================================
Este programa calcula a razão e ângulo de descida para diferentes configurações de área molhada e alt-dens.

 Figura 1 - Fixo altitude densidade de 1212m e variando setups dos aviões
        Subplot 1 - Razão de decida x velocidade horizontal
        Subplot 2 - Ângulo de descida x Velocidade horizontal
   
 Figura 2 - Fixo o avião Zb e variando alt-dens
        Subplot 1 - Razão de descida x velocidade horizontal
        Subplot 2 - Ângulo de descida x velocidade horizontal

"""

Cl = np.linspace(0.1, Zb.CLmax)
V = np.linspace(0.1, 20)

# =======================================        FIGURA 2      ======================================

theta, RS, Vh = Zb.sink_Rate(Cl)
theta2, RS2, Vh2 = Zb.sink_Rate(Cl,1.15)
theta3, RS3, Vh3 = Zb.sink_Rate(Cl,1.0887)
theta4, RS4, Vh4 = Zb.sink_Rate(Cl,1)

#PLOTAGEM SUBPLOT 1 FIGURA 2
fig, (ax3, ax4) = plt.subplots(figsize=(18, 5),nrows=1, ncols=2)
fig.suptitle('Descida calculada para o Zb variando a alt-dens')


ax3.set(title='Razão de descida', xlabel='Velocidade horizontal [m/s]'
      , ylabel='Razão de descida [m/s] ')

ax3.plot(Vh, -RS,'--',color='cyan', label= 'Altitude-densidade 0$m$')
ax3.plot(Vh2, -RS2,'--',color='r', label= f'Altitude-densidade {round(zb.alt2rho(rho=1.15))}$m$')
ax3.plot(Vh3, -RS3,color='b', label= f'Altitude-densidade {round(zb.alt2rho(rho=1.0887))}$m$')
ax3.plot(Vh4, -RS4,'--', color='orange', label= f'Altitude-densidade {round(zb.alt2rho(rho=1))}$m$')

ax3.legend()
ax3.set_ylim(-5,0)

ax3.grid()

#PLOTAGEM SUBPLOT 2 FIGURA 2

ax4.set(title='Ângulo de descida', xlabel='Velocidade horizontal [m/s]'
       , ylabel='Ângulo de descida [graus]')

ax4.plot(Vh, -theta,'--',color='cyan', label= f'Altitude-densidade 0$m$')
ax4.plot(Vh2, -theta2,'--',color='r', label= f'Altitude-densidade {round(zb.alt2rho(rho=1.15))}$m$')
ax4.plot(Vh3, -theta3,color='b', label= f'Altitude-densidade {round(zb.alt2rho(rho=1.0887))}$m$')
ax4.plot(Vh4, -theta4,'--', color='orange', label= f'Altitude-densidade {round(zb.alt2rho(rho=1))}$m$')

ax4.legend()
ax4.set_ylim(-15,0)

ax4.grid()

#------------------------- CARGA PAGAS DIFERENTES -------------------------------------

Cl = np.linspace(0.1, Zb.CLmax)
V = np.linspace(0.1, 20)

# =======================================        FIGURA 2      ======================================
Carga = np.array((5, 5.5, 6, 6.5))

#PLOTAGEM SUBPLOT 1 FIGURA 2
fig, (ax3, ax4) = plt.subplots(figsize=(18, 5),nrows=1, ncols=2)
#fig.suptitle('Descida calculada para o Zb variando a alt-dens')


ax3.set(title='Razão de descida', xlabel='Velocidade horizontal [m/s]'
      , ylabel='Razão de descida [m/s] ')

for w in Carga:
    Zb.Load = w
    Zb.params_Calc
    theta, RS, Vh = Zb.sink_Rate(Cl, zb.alt2rho(1212))
    ax3.plot(Vh, -RS, label= f'Carga paga {w}Kg')

ax3.legend()
ax3.set_xlim(10, 20)
ax3.set_ylim(-5,-2)

ax3.grid()

#PLOTAGEM SUBPLOT 2 FIGURA 2

ax4.set(title='Ângulo de descida', xlabel='Velocidade horizontal [m/s]'
       , ylabel='Ângulo de descida [graus]')

for w in Carga:
    Zb.Load = w
    Zb.params_Calc
    theta, RS, Vh = Zb.sink_Rate(Cl, zb.alt2rho(1212))
    ax4.plot(Vh, -theta, label= f'Carga paga {w}Kg')
    

ax4.legend()
ax4.set_xlim(10, 20)
ax4.set_ylim(-15, -10)

ax4.grid()

# %% [markdown]
# # Pouso

# %% [markdown]
# ## Dinâmica

# %% [markdown]
# \begin{equation}
#     L = \frac{1}{2} \rho v^2 S C_{L}
# \end{equation}
#
# \begin{equation}
#     D = \frac{1}{2} \rho v^2 S (C_{D0} + \varphi K C_{L}^2 )
# \end{equation}
#
# \begin{equation}
#     Fat = \mu_{r}(W-L)
# \end{equation}
#
# \begin{equation}
#     \phi = \frac{(16h/b)^2}{1 +(16h/b)^2}
# \end{equation}

# %%
Densidade = np.array((zb.alt2rho(912), zb.alt2rho(1212), zb.alt2rho(1512)))   #Densidade do ar desvio de 300m
Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen'))
Markers =  np.array(('--', '-', '--'))

fig, ax = plt.subplots(1, 2, figsize=(20,6))
ax[0].set(title=r'Dinâmica do pouso alt-dens 1212m $\pm$ 73m', xlabel='Tempo (s)', ylabel='Forças aerodinâmicas (N)')
ax[1].set(title='Dinâmica do pouso alt-dens 1212m $\pm$ 73m', xlabel='Tempo (s)', ylabel='Forças aerodinâmicas (N)')

for dens, marks in zip(Densidade, Markers):
    Vl, V, L, D, Fat = Zb.Landing_Forces(dens)
    t, d, V, a = Zb.landing_Kinematic_EDO(19, dens)

    ax[0].plot(t, L, linestyle=marks, color=Cores[0], label='Sustentação')
    ax[0].plot(t, D,  linestyle=marks, color=Cores[1], label='Arrasto')
    ax[1].plot(t, Fat,  linestyle=marks, color=Cores[2], label='Força de atrito')
    ax[0].plot(t, Fat/Zb.mi,  linestyle=marks, color=Cores[3], label='Relação W-L (força normal)')

    ax[0].set_xlim(0, Vl) #Fica melhor se colocar em escala de logaritmo
    ax[0].set_ylim(0)
    ax[0].legend()
    ax[0].grid(linestyle='dotted')
    
    ax[1].legend()
    ax[1].grid(linestyle='dotted')

# %% [markdown]
# ## Cinemática
# EDO de pouso
#
# \begin{equation}
#     \frac{\mathrm{d}v(t) }{\mathrm{d} t} = - D - \mu_{r}(W-L)
# \end{equation}
#
# Assim, obtém-se a função $v_{l}(t)$:
#
# \begin{equation}
#     v_{l}(t) = \int_{t_{vl}}^{0} - D - (\mu_{r}(W-L)) dt
#     \label{eq:vp(t)}
# \end{equation}
#
# Para obtenção de $s(t)$ e $a(t)$, tem-se:
# \begin{equation}
#     s(t) = \int_{t_{vl}}^{0} v_{l}(t) dt
#     \label{eq:sp(t)}
# \end{equation}
#
# \begin{equation}
#     a(t) = \frac{\mathrm{d} v_{l}(t) }{\mathrm{d} t}
#     \label{eq:ap(t)}
# \end{equation}

# %%
"""
Created on Sat Jun  5 09:09:02 2021

@author: Arthur Chabole
=============================
Performance cinemática do pouso.

"""
# Definindo domínio
t_final = 18
pesos = np.linspace(4, 7, 4)

# Colores e marcadores (beautilfy)
Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen'))
Markers = np.array(('^', 'o', 'd', 'v', '.'))
Lines = np.array(('--', '-', '--', '--'))

# Gráficos
fig, ax = plt.subplots(figsize=(19.5, 5),nrows=1, ncols=3)

ax[0].set(title='Velocidade no pouso',
       xlabel='Tempo (s)', ylabel='Velocidade (m/s)')
ax[1].set(title='Aceleração no pouso', xlabel='Tempo (s)',
        ylabel='Acelerção $(m/s^2)$')
ax[2].set(title='Espaço no pouso', xlabel='Tempo (s)',
        ylabel='Distância de pista (m)')

'''ax4.set(title='Cinemática do pouso',
        xlabel='Tempo (s)', ylabel='Valores numéricos')'''

for (p, cor, mark) in zip(pesos, Cores, Markers):
    Zb = zb.Airplane(Load=p)

    Zb.C_D0 = 0.1

    # Usando os métodos
    tempo, S_on, V_on, a_on = Zb.landing_Kinematic_EDO(
        t_final, Ground_Effect=True)
    
    tempo, S_off, V_off, a_off = Zb.landing_Kinematic_EDO(t_final)

    #Vlo_index = get_index_of_nearest_element(V_off, Zb.veloc_Req(Zb.CLmax)*1.2)

    #ax.plot(tempo, V_on, color= cor, label=f'Efeito solo ON: Carga paga {p}Kg')
    ax[0].plot(tempo, V_off, '--', color=cor,
            label=f'Carga paga {p}Kg')
    #ax.axvline(x=tempo[Vlo_index], ymin= 0, ymax= 20, color= cor)

    #ax2.plot(tempo, a_on, color= cor, label=f'Efeito solo ON: Carga paga {p}Kg')
    ax[1].plot(tempo, a_off, '--', color=cor,
             label=f'Carga paga {p}Kg')
    #ax2.axvline(x=tempo[Vlo_index], ymin=0, ymax= 8, color= cor)

    #ax3.plot(tempo, S_on, color= cor, label=f'Efeito solo ON: Carga paga {p}Kg')
    ax[2].plot(tempo, S_off, '--', color=cor,
             label=f'Carga paga {p}Kg')
    #ax3.axvline(x=tempo[Vlo_index], ymin= 0, ymax= 50, color= cor)

    '''ax4.plot(tempo, V_off, '--', marker=Markers[0], color=cor,
             label=f'Velocidade, Carga paga {p}Kg')
    ax4.plot(tempo, -a_off, '--', marker=Markers[1], color=cor,
             label=f'Aceleração')
    ax4.plot(tempo, S_off, '--', marker=Markers[2], color=cor,
             label=f'Espaço')'''

# Formatar gráfico 4 para escala logaritmica
#ax4.set_yscale('log')
#ax4.set_ylim(0.3)

# Beautilfy
for graf in ax:
    graf.legend()
    graf.set_xlim(0)
    graf.grid(linestyle='dotted')
    
plt.show()

# %%
Densidade = np.array((zb.alt2rho(912), zb.alt2rho(1212), zb.alt2rho(1512)))   #Densidade do ar desvio de 300m
Cores = np.array(('red', 'blue', 'orange', 'purple', 'limegreen'))
Markers =  np.array(('--', '-', '--'))

fig, ax = plt.subplots(1, 2, figsize=(15,6))
ax[0].set(title=r'Cinemática do pouso alt-dens 1212m $\pm$ 73m', xlabel='Tempo (s)', ylabel='Valores numéricos')
ax[1].set(title='Cinemática do pouso alt-dens 1212m $\pm$ 73m', xlabel='Tempo (s)', ylabel='Valores numéricos')


for dens, marks in zip(Densidade, Markers):
    Vl, V, L, D, Fat = Zb.Landing_Forces(dens)
    t, d, V, a = Zb.landing_Kinematic_EDO(19, dens)

    ax[1].plot(t, V,  linestyle=marks,  color=Cores[0], label='Velocidade (m/s)')
    ax[1].plot(t, a,  linestyle=marks,  color=Cores[1], label='Aceleração ($m/s^2$)')
    ax[0].plot(t, d,  linestyle=marks,  color=Cores[3], label='Distância (m)')

    ax[1].set_xlim(0, Vl) #Fica melhor se colocar em escala de logaritmo
    #ax[1].set_ylim(0)
    ax[1].legend()
    ax[1].grid(linestyle='dotted')
    
    ax[0].legend()
    ax[0].grid(linestyle='dotted')

# %%
"""
Created on Sat Mar 27 17:49:05 2021

@author: Arthur Chabole
===============================
Este programa calcula o comprimento de pista para decolagem x altitude-densidade para varias cargas pagas
                                                                            usando a biblioteca zebralib.    
    Figura 1 - Altitude-densidade x Distância de pista
            Com cargas diferentes.
      
    Figura 2 - Distância de pista x Altitude-densidade 
            Com cargas diferentes.
            
O efeito solo pode ser considerado ou não. Caso seja considerado, "descomente" as linhas 60-63 e 84-87
"""

Zb = zb.Airplane(CLn=1.75, CLmax=2.26, Load=4.5)
Zb2 = zb.Airplane(CLn=1.75, CLmax=2.26, Load=5.5)
Zb3 = zb.Airplane(CLn=1.75, CLmax=2.26, Load=6)                #Constroi os objetos
Zb4 = zb.Airplane(CLn=1.75, CLmax=2.26, Load=6.5)

Densidade = np.linspace(1.225, 0.8) 
AltDens = zb.iterate_rho2alt(Densidade)

# Sem considerar o efeito solo 'False'
Slo =  np.array(Zb.landing_Distance_Miranda(Densidade, False))
Slo2 = np.array(Zb2.landing_Distance_Miranda(Densidade, False))
Slo3 = np.array(Zb3.landing_Distance_Miranda(Densidade, False))
Slo4 = np.array(Zb4.landing_Distance_Miranda(Densidade, False))

# Considerando o efeito solo do avião 'True'
S =  np.array(Zb.landing_Distance_Miranda(Densidade, True))
S2 = np.array(Zb2.landing_Distance_Miranda(Densidade, True))
S3 = np.array(Zb3.landing_Distance_Miranda(Densidade, True))
S4 = np.array(Zb4.landing_Distance_Miranda(Densidade, True))

#PLOTAGEM
fig, ax = plt.subplots(figsize=(7, 5))

#INSPIRADO NA AIRBUS
ax.set(title='Altitude-Densidade x  Distância de pouso', xlabel=' Distância de pouso [m]',
          ylabel='Altitude-Densidade [m]', label=' - Sem efeito solo e -- com efeito solo')

# Sem considerar o efeito solo 'False'
ax.plot(Slo, AltDens, color= 'b',  label= f'Carga de {round(Zb.Load,2)}Kg sem efeito solo' )
ax.plot(Slo2, AltDens, color='g', label= f'Carga de {round(Zb2.Load,2)}Kg')
ax.plot(Slo3, AltDens, color= 'm', label= f'Carga de {round(Zb3.Load,2)}Kg ')
ax.plot(Slo4, AltDens, color= 'orange', label= f'Carga de {round(Zb4.Load,2)}Kg')

#Considerando o efeito solo do avião 'True'
'''ax.plot(S, AltDens, '--', color= 'b', label= f'Carga de {round(Zb.Load,2)}Kg com efeito solo' )
ax.plot(S2, AltDens, '--', color= 'g', label= f'Carga de {round(Zb2.Load,2)}Kg ')
ax.plot(S3, AltDens, '--', color= 'm', label= f'Carga de {round(Zb3.Load,2)}Kg ')
ax.plot(S4, AltDens, '--', color= 'orange', label= f'Carga de {round(Zb4.Load,2)}Kg ')
'''
ax.plot([-5,180], [1212]*2,  linestyle='dashdot', color= 'r', label= 'Altitude-Densidade de SJC 1212m' )

ax.set_ylim(0)
ax.set_xlim(25,60)

ax.legend()
ax.grid(linestyle='dotted', linewidth=1)

# %% [markdown]
# ## Envelope de voo

# %%
Zb.Load = 5.5
Zb.params_Calc

rho= np.linspace(0.6375, 1.225, 10000)

V = np.linspace(0.1, 28, 1000)
vmin, vmax, vstall, vstr = Zb.envope_Voo(V, rho) #BadAss
# Out:
# não convergiu com 200 iterações!
# não convergiu com 200 iterações!

# %%
fig, ax = plt.subplots(figsize=(10, 6))
    
ax.plot(vmin, zb.iterate_rho2alt(rho), color='blue', label='Vmín propulsiva')
ax.plot(vmax, zb.iterate_rho2alt(rho), color='red', label='Vmáx propulsiva')
ax.hlines(1212, 0, 25, linestyle='--', label='Alt-dens de SJC 1212m')

ax.plot(vstr, zb.iterate_rho2alt(rho), color='purple', label='Vmáx estrutural')
ax.plot(vstall, zb.iterate_rho2alt(rho), color='green', label='Vestol')
ax.grid(linestyle='dotted')
ax.set_ylabel('Altitude-densidade (m)')
ax.set_xlabel('Velocidade (m/s)')
ax.set_xlim(5, 25)
ax.set_ylim(0)
ax.legend()

# %% [markdown]
# ## Previsão de tempo de missão

# %%
#Caracteríticas básicas o avião
Zb.mission_Time(zb.alt2rho(1212))
# Out:
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1541: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.degrees(np.arcsin(RC / V))
#                     Zb default
# Alt-dens                  0.00
# Tempo de decolagem        3.75
# Tempo de subida           0.57
# Tempo de cruzeiro        62.23
# Tempo de descida          0.44
# TEMPO TOTAL              66.99

# %% [markdown]
# ## Método para mostrar os outputs

# %%
#Caracteríticas básicas o avião
Zb.airplane_Info(zb.alt2rho(1212))
# Out:
# C:\Users\arthu\anaconda3\ZebraLib\zebralib\zebraperformance.py:1541: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.degrees(np.arcsin(RC / V))
#                                    Zb default
# Alt-dens [m]                             1212
# Densidade [Kg/m^3]                   1.088654
# Informações de carga                ---------
# Carga_paga                                5.5
# Carga_vazia                               2.8
# Carga_total                               8.4
# Peso_total                             82.404
# Informações aerodinâmicas           ---------
# S                                       0.843
# b                                        1.86
# Swet                                       10
# C_D0                                 0.115658
# CLn                                      1.75
# CLmax                                    2.26
# c                                       0.463
# AR                                   4.103915
# Af                                      0.601
# CLmax_Alc                            1.090895
# CLmax_Aut                            1.889486
# Eficmax                              4.716024
# N_max                                     2.1
# Informações de velocidades          ---------
# V_stol                               8.914072
# V_decolagem                         10.696887
# V_aproximação                       11.588294
# VstruturalMax                       12.917718
# Vcruzeiro                           11.625946
# VmaxAlcance                          12.83036
# VmaxAutonomia                        9.748965
# Informações de Decolagem/subida     ---------
# Distancia_decolagem(c/efeito_solo)  23.582429
# Distancia_decolagem(s/efeito_solo)  26.587653
# CL_distancia_min_decolagem           0.225076
# Razão_max_subida                     2.167234
# Angulo_razao_max_subida              8.689547
# Raio_subida                         56.375775
# Angulo_max_subida                    9.904525
# Velocidade_angulo_max_subida        15.165122
# CL_Ang_max_subida                    1.090895
# Informações de aproximação/pouso    ---------
# Distancia_pouso(c/efeito_solo)      61.022925
# Distancia_pouso(s/efeito_solo)      54.293518
# Angulo_maxAlcance                   11.971845
# Razao_maxAlcance                     2.632312
# Angulo_min_planeio                  11.971845
# Velocidade_Angulo_min_planeio       16.650118
# Raio_descida                        61.272205
# Flare_altura                         1.332692
# Flare_distancia                     12.709756
